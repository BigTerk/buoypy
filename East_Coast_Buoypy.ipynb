# %% [markdown]
# ## Example call
# import buoypy.py as bp
#
#  #Get the last 45 days of data
#
# rt = bp.realtime(41013) #frying pan shoals buoy
#
# ocean_data = rt.get_ocean()  #get Oceanographic data
#
# wave_data.head()

# %%
import buoypy as bp
rt = bp.realtime(41013) #frying pan shoals buoy
#ocean_data = rt.get_ocean() #get Oceanographic data
#wave_data.head()
print(rt)
#rt.data_spec()
#rt.ocean()  <---- Link is broken

print(rt.txt())

hist = bp.historic_data(41013,2016,0)
print(hist)
hist.get_stand_meteo()
# Out:
# ...
#                       WDIR  WSPD   GST  WVHT  DPD  APD    MWD    PRES  ATMP  \
# Date
# 2018-03-16 14:20:00  270.0  11.0  14.0   NaN  NaN  NaN    NaN  1014.1  15.2
# 2018-03-16 14:10:00  270.0  11.0  14.0   NaN  NaN  NaN    NaN  1014.0  15.2
# 2018-03-16 14:00:00  280.0  12.0  14.0   NaN  NaN  NaN    NaN  1013.9  15.3
# 2018-03-16 13:50:00  280.0  11.0  16.0   1.9  NaN  5.0  234.0     NaN  15.3
# 2018-03-16 13:40:00  270.0  12.0  14.0   NaN  NaN  NaN    NaN  1013.8  15.3
# 2018-03-16 13:30:00  270.0  11.0  14.0   NaN  NaN  NaN    NaN  1013.8  15.5
# 2018-03-16 13:20:00  270.0  11.0  15.0   NaN  NaN  NaN    NaN  1013.7  15.5
# 2018-03-16 13:10:00  270.0  11.0  14.0   NaN  NaN  NaN    NaN  1013.6  15.6
# 2018-03-16 13:00:00  270.0  12.0  15.0   NaN  NaN  NaN    NaN     NaN  15.7
# 2018-03-16 12:50:00  270.0  12.0  15.0   2.0  8.0  5.0  221.0  1013.4  15.8
# 2018-03-16 12:40:00  270.0  12.0  14.0   2.0  NaN  5.0  221.0  1013.3  15.9
# ...

# %%
import pandas as pd
df = pd.DataFrame
date_str = df.YY + ' ' + df.MM+ ' ' + df.DD + ' ' + df.hh + ' ' + df.mm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a788ddd474aa> in <module>()
#       1 import pandas as pd
#       2 df = pd.DataFrame
# ----> 3 date_str = df.YY + ' ' + df.MM+ ' ' + df.DD + ' ' + df.hh + ' ' + df.mm
#
# AttributeError: type object 'DataFrame' has no attribute 'YY'
